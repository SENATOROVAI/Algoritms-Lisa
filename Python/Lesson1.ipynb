# %%
Linter(black) это инcтрумент анализа и поиска ошибок согласно PEP8
MyPy инструмент анализа аннотации типов

# %% [markdown]
# ### Введение в алгоритмы и структуры данных

# %% [markdown]
# **Модель вычисления Ram** - абстрактная модель время вичисления алгоритма которая считает количество выполняемых шагов
# ,за основу взята любая операция +=-  требуется 1 шаг для выполнения
# время исполения цикла завитст от клова итераций
# итерация - 1 проход программы в цикле
# каждое обращений к памяти 1 временной шаг
